# %% [markdown]
# # 종합 통계 실습
#
# ## 비즈니스 시나리오
#
# > 여러분은 식품·와인 유통 기업 **FreshCart**의 데이터 분석팀 인턴입니다. \
# > 마케팅팀이 6차례 캠페인을 진행했지만 수락률이 낮아 경영진이 우려하고 있습니다. \
# > 고객 데이터를 분석하여 **다음 캠페인의 집중 공략 전략**을 수립해 주세요.
#
# ---
#
# | Part | 주제 | 핵심 질문 |
# |------|------|-----------|
# | **Part 0** | 데이터 전처리 | (코드 제공) |
# | **Part 1** | 탐색적 데이터 분석 | 고객은 누구인가? |
# | **Part 2** | 확률분포 모델링 | 고객 행동은 어떤 패턴을 따르는가? |
# | **Part 3** | 추정과 가설검정 | 고소득 고객과 저소득 고객의 소비는 다른가? |
# | **Part 4** | 고급 검정 | 교육, 결혼, 캠페인 반응의 관계는? |
# | **Part 5** | 상관분석 / 비율 비교 | 변수 간 관계를 파악하고, 캠페인 효과를 검증할 수 있는가? |
# | **Challenge** | 종합 분석 보고서 | 다음 캠페인 타겟은 누구인가? |

# %% [markdown]
# ### 데이터 셋 개요
#
# | 항목 | 내용 |
# |------|------|
# | **출처** | Kaggle |
# | **URL** | https://www.kaggle.com/datasets/imakash3011/customer-personality-analysis |
# | **크기** | 약 2,240행 × 29열 |
# | **파일명** | `marketing_campaign.csv` |
# | **도메인** | 식품·와인 유통 기업 |
#
# **설명:** 고객 성격 분석은 기업의 이상적인 고객을 심층 분석하는 방법론이다. 고객 세그먼트별 니즈·행동·관심사를 파악해 제품 및 마케팅을 최적화하는 데 활용한다.
#
# ---
#
# ### 변수 목록
#
# #### 고객 정보
#
# | # | 변수명 | 설명 |
# |---|--------|------|
# | 1 | `ID` | 고객 고유 식별자 |
# | 2 | `Year_Birth` | 고객 출생연도 |
# | 3 | `Education` | 최종 학력 |
# | 4 | `Marital_Status` | 결혼 상태 |
# | 5 | `Income` | 연간 가구 소득 |
# | 6 | `Kidhome` | 가구 내 어린 자녀 수 |
# | 7 | `Teenhome` | 가구 내 십대 자녀 수 |
# | 8 | `Dt_Customer` | 고객 등록일 |
# | 9 | `Recency` | 마지막 구매 이후 경과 일수 |
#
# ---
#
# #### 소비 패턴 — 최근 2년간 지출 금액
#
# | # | 변수명 | 설명 |
# |---|--------|------|
# | 10 | `MntWines` | 와인 지출 금액 |
# | 11 | `MntFruits` | 과일 지출 금액 |
# | 12 | `MntMeatProducts` | 육류 지출 금액 |
# | 13 | `MntFishProducts` | 생선 지출 금액 |
# | 14 | `MntSweetProducts` | 과자·디저트 지출 금액 |
# | 15 | `MntGoldProds` | 골드 지출 금액 |
#
# ---
#
# #### 캠페인 반응
#
# | # | 변수명 | 설명 |
# |---|--------|------|
# | 16 | `NumDealsPurchases` | 할인 적용 구매 횟수 |
# | 17 | `NumWebPurchases` | 웹사이트를 통한 구매 횟수 |
# | 18 | `NumCatalogPurchases` | 카탈로그를 통한 구매 횟수 |
# | 19 | `NumStorePurchases` | 오프라인 매장 구매 횟수 |
# | 20 | `NumWebVisitsMonth` | 최근 한 달간 웹사이트 방문 횟수 |
# | 21 | `AcceptedCmp3` | 3차 캠페인 제안 수락 여부 (1=수락, 0=거절) |
# | 22 | `AcceptedCmp4` | 4차 캠페인 제안 수락 여부 |
# | 23 | `AcceptedCmp5` | 5차 캠페인 제안 수락 여부 |
# | 24 | `AcceptedCmp1` | 1차 캠페인 제안 수락 여부 |
# | 25 | `AcceptedCmp2` | 2차 캠페인 제안 수락 여부 |
# | 26 | `Complain` | 최근 2년 내 불만 제기 여부 (1=있음, 0=없음) |
# | 27 | `Z_CostContact` | 상수값 3 — 캠페인 1회당 연락 비용 |
# | 28 | `Z_Revenue` | 상수값 11 — 캠페인 성공 시 수익 |
# | 29 | `Response` | 최종 캠페인 제안 수락 여부 **(타깃 변수)** |

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import trim_mean
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.proportion import (
    proportions_ztest, proportion_confint, proportion_effectsize
)
from statsmodels.stats.power import NormalIndPower, TTestIndPower
import pingouin as pg
import warnings
import platform

warnings.filterwarnings('ignore')

if platform.system() == 'Windows':
    plt.rcParams['font.family'] = 'Malgun Gothic'
elif platform.system() == 'Darwin':
    plt.rcParams['font.family'] = 'AppleGothic'
else:
    plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False

COLORS = {
    'blue': '#3B82F6', 'indigo': '#6366F1', 'violet': '#8B5CF6',
    'teal': '#14B8A6', 'emerald': '#10B981', 'amber': '#F59E0B',
    'rose': '#F43F5E', 'red': '#EF4444', 'slate': '#64748B',
    'sky': '#0EA5E9', 'purple': '#A855F7', 'lime': '#84CC16',
}

# %% [markdown]
# ---
# ## Part 0: 데이터 전처리 (코드 제공)
#
# 아래 코드를 실행하여 분석에 사용할 데이터프레임 `df`를 준비합니다.
# 모든 파생변수가 생성되고 이상치가 제거된 상태에서 Part 1부터 분석을 시작합니다.

# %% [markdown]
# ### 0-1. 데이터 로드 및 결측치 처리

# %%
df = pd.read_csv('data/marketing_campaign.csv', sep='\t')
print(f"원본 데이터: {df.shape[0]}행 × {df.shape[1]}열")
print(f"Income 결측치: {df['Income'].isnull().sum()}개")

df['Income'] = df['Income'].fillna(df['Income'].median())
print(f"→ Income 중앙값({df['Income'].median():,.0f})으로 대치 완료")
# Out:
# 원본 데이터: 2240행 × 29열
# Income 결측치: 24개
# → Income 중앙값(51,382)으로 대치 완료

# %% [markdown]
# ### 0-2. 파생변수 생성

# %%
spending_cols = ['MntWines', 'MntFruits', 'MntMeatProducts',
                 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']
purchase_cols = ['NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases']
campaign_cols = ['AcceptedCmp1', 'AcceptedCmp2', 'AcceptedCmp3',
                 'AcceptedCmp4', 'AcceptedCmp5', 'Response']

df['Age'] = 2024 - df['Year_Birth']
df['Total_Spending'] = df[spending_cols].sum(axis=1)
df['Total_Purchases'] = df[purchase_cols].sum(axis=1)
df['Total_Accepted'] = df[campaign_cols].sum(axis=1)
df['Has_Children'] = (df['Kidhome'] + df['Teenhome']) > 0
df['Income_Group'] = pd.qcut(df['Income'], 3, labels=['Low', 'Mid', 'High'])

bins = [0, 39, 49, 59, 200]
labels_age = ['30대 이하', '40대', '50대', '60대 이상']
df['Age_Group'] = pd.cut(df['Age'], bins=bins, labels=labels_age)

edu_map = {'Basic': 'Undergraduate', '2n Cycle': 'Undergraduate',
           'Graduation': 'Graduate', 'Master': 'Postgraduate', 'PhD': 'Postgraduate'}
df['Education_Group'] = df['Education'].map(edu_map)

marital_map = {'Married': 'Together', 'Together': 'Together',
               'Single': 'Single', 'Divorced': 'Single', 'Widow': 'Single',
               'Alone': 'Single', 'Absurd': 'Single', 'YOLO': 'Single'}
df['Marital_Group'] = df['Marital_Status'].map(marital_map)

df['Campaign_Response'] = df['Total_Accepted'] > 0

df['Dt_Customer'] = pd.to_datetime(df['Dt_Customer'], format='%d-%m-%Y')
reference_date = df['Dt_Customer'].max()
df['Customer_Days'] = (reference_date - df['Dt_Customer']).dt.days

print("파생변수 생성 완료:")
for col in ['Age', 'Total_Spending', 'Total_Purchases', 'Total_Accepted',
            'Has_Children', 'Income_Group', 'Age_Group', 'Education_Group',
            'Marital_Group', 'Campaign_Response', 'Customer_Days']:
    print(f"  - {col}: {df[col].dtype}")
# Out:
# 파생변수 생성 완료:
#   - Age: int64
#   - Total_Spending: int64
#   - Total_Purchases: int64
#   - Total_Accepted: int64
#   - Has_Children: bool
#   - Income_Group: category
#   - Age_Group: category
#   - Education_Group: str
#   - Marital_Group: str
#   - Campaign_Response: bool
#   - Customer_Days: int64

# %% [markdown]
# ### 0-3. 이상치 제거

# %%
n_before = len(df)
df = df[(df['Age'] <= 100) & (df['Income'] <= 200000)].copy()
n_after = len(df)
print(f"이상치 제거: {n_before}행 → {n_after}행 ({n_before - n_after}행 제거)")
print(f"\n최종 데이터 요약:")
print(f"  Age 범위: {df['Age'].min()} ~ {df['Age'].max()}")
print(f"  Income 범위: {df['Income'].min():,.0f} ~ {df['Income'].max():,.0f}")
print(f"\n데이터 준비가 완료되었습니다. Part 1부터 분석을 시작하세요!")
# Out:
# 이상치 제거: 2240행 → 2236행 (4행 제거)
#
# 최종 데이터 요약:
#   Age 범위: 28 ~ 84
#   Income 범위: 1,730 ~ 162,397
#
# 데이터 준비가 완료되었습니다. Part 1부터 분석을 시작하세요!

# %% [markdown]
# ---
# ## Part 1: 탐색적 데이터 분석 — "고객은 누구인가?"
#
# 기술통계량과 시각화를 통해 FreshCart 고객의 특성을 파악합니다.

# %% [markdown]
# ### 문제 1-1. 중심경향과 산포도
#
# `Income`, `Total_Spending`, `Age` 세 변수에 대해 다음을 계산하세요.
#
# | 중심경향 | 산포도 |
# |----------|--------|
# | 평균(mean) | 분산(variance) |
# | 중앙값(median) | 표준편차(std) |
# | 최빈값(mode) | 사분위범위(IQR) |
# | 5% 절사평균(trimmed mean) | 변동계수(CV) |

# %%
# TODO 1-1(a): Income, Total_Spending, Age의 중심경향 — 평균, 중앙값, 최빈값, 5% 절사평균
q1_1_df = df[['Income', 'Total_Spending', 'Age']]
q1_1_df.head()
q1_1_mean = q1_1_df.mean()
q1_1_df_median = q1_1_df.median()
q1_1_df_mode = q1_1_df.mode()
display(q1_1_mean) #평균
display(q1_1_df_median) #중앙값
display(q1_1_df_mode) # 최빈값
for i in ['Income', 'Total_Spending', 'Age']:
    trim = stats.trim_mean(q1_1_df[i],0.05)
    print(f'{i} 5% 절사평균: {trim:.4f}')
# Out:
# Income            51952.614043
# Total_Spending      605.986583
# Age                  55.101968
# dtype: float64
# Income            51381.5
# Total_Spending      396.5
# Age                  54.0
# dtype: float64
#     Income  Total_Spending  Age
# 0  51381.5              46   48
# Income 5% 절사평균: 51740.1534
# Total_Spending 5% 절사평균: 561.1197
# Age 5% 절사평균: 55.0750

# %%
# TODO 1-1(b): Income, Total_Spending, Age의 산포도 — 분산(ddof=1), 표준편차, IQR, CV(%)
q1_1_var = q1_1_df.var(ddof=1)#분산
display(q1_1_var)
q1_1_std = q1_1_df.std(ddof=1)#표준편차
display(q1_1_std)
q1_1_iqr = q1_1_df.quantile(0.75)-q1_1_df.quantile(0.25)#iqr
display(q1_1_iqr)
for i in ['Income', 'Total_Spending', 'Age']:
    cv = (q1_1_df[i].std(ddof=1) / q1_1_df[i].mean()) * 100
    print(f'{i}의 변동계수: {cv:.4f}')
# Out:
# Income            4.584509e+08
# Total_Spending    3.622417e+05
# Age               1.369668e+02
# dtype: float64
# Income            21411.466851
# Total_Spending      601.865156
# Age                  11.703281
# dtype: float64
# Income            32773.25
# Total_Spending      976.50
# Age                  18.00
# dtype: float64
# Income의 변동계수: 41.2135
# Total_Spending의 변동계수: 99.3199
# Age의 변동계수: 21.2393

# %% [markdown]
# ### 문제 1-2. 분포 시각화
#
# - **(a)** Income 히스토그램 + KDE + 평균/중앙값 수직선
# - **(b)** Total_Spending 수평 박스플롯 + IQR 기준 이상치 개수 출력
# - **(c)** Income_Group별 Total_Spending 바이올린 플롯

# %%
# TODO 1-2(a): Income 히스토그램 + KDE
fig, ax = plt.subplots(figsize = (6,3))
sns.histplot(q1_1_df['Income'], kde=True)
ax.set_xlabel('Income')
plt.tight_layout
plt.show()

# %%
# TODO 1-2(b): Total_Spending 박스플롯 + IQR 기준 이상치
fig, ax = plt.subplots(figsize=(6,3))
sns.boxplot(q1_1_df['Total_Spending'])
q1_ts = q1_1_df['Total_Spending'].quantile(0.25)
q3_ts = q1_1_df['Total_Spending'].quantile(0.75)
iqr_ts = q3_ts - q1_ts
iqr_upper = q3_ts + 1.5 * iqr_ts
iqr_lower = q1_ts - 1.5 * iqr_ts

outlier = q1_1_df[(q1_1_df['Total_Spending'] > iqr_upper) |  (q1_1_df['Total_Spending'] < iqr_lower)]
print(len(outlier))
# Out:
# 3

# %%
# TODO 1-2(c): Income_Group별 Total_Spending 바이올린 플롯
fig, ax = plt.subplots(figsize=(6,3))
sns.violinplot(df,x = 'Income_Group', y = 'Total_Spending', order=['Low', 'Mid', 'High'])
# Out:
# <Axes: xlabel='Income_Group', ylabel='Total_Spending'>

# %% [markdown]
# ### 문제 1-3. 왜도와 첨도
#
# 6개 소비 카테고리(MntWines ~ MntGoldProds)의 왜도(Skewness)와 첨도(Kurtosis)를 계산하고,
# 2×3 히스토그램 그리드를 그려 분포 형태를 비교하세요.
#
# **왜도 해석**
# - 왜도 > 0: 오른쪽 꼬리가 긴 분포
# - 왜도 < 0: 왼쪽 꼬리가 긴 분포
# - 왜도 ≈ 0: 좌우 대칭에 가까운 분포
#
# **첨도 해석**
# - 초과 첨도 > 0: 정규분포보다 중앙이 뾰족하고 꼬리가 두꺼운 분포
# - 초과 첨도 < 0: 정규분포보다 중앙이 평평하고 꼬리가 얇은 분포
# - 초과 첨도 ≈ 0: 정규분포와 유사한 형태

# %%
spending_names = ['Wines', 'Fruits', 'Meat', 'Fish', 'Sweet', 'Gold']
hist_colors = [COLORS['blue'], COLORS['violet'], COLORS['teal'],
               COLORS['emerald'], COLORS['amber'], COLORS['rose']]


# TODO 1-3(a): 6개 카테고리의 왜도/첨도 계산 및 출력
for i in spending_names:
    filtered_df = df.filter(like=i)
    for col in filtered_df:
        skew = filtered_df[col].skew()
        kurt = filtered_df[col].kurt()
        print(f'{i}의 왜도: {skew:.4f}, 첨도: {kurt:.4f}')
# Out:
# Wines의 왜도: 1.1760, 첨도: 0.6005
# Fruits의 왜도: 2.1042, 첨도: 4.0698
# Meat의 왜도: 2.0853, 첨도: 5.5301
# Fish의 왜도: 1.9200, 첨도: 3.0960
# Sweet의 왜도: 2.1357, 첨도: 4.3721
# Gold의 왜도: 1.8851, 첨도: 3.5583

# %%
# TODO 1-3(b): 2×3 히스토그램 그리드 (각 카테고리 분포 + 평균선)
fig, axes = plt.subplots(2, 3, figsize=(12, 6))
axes = axes.flatten()
cols = []
for name in spending_names:
    cols.extend(df.filter(like=name).columns)
cols = list(set(cols))    

for idx, col in enumerate(cols):
    sns.histplot(df[col], ax=axes[idx], kde=True, color= hist_colors[idx])
    mean_val = df[col].mean()
    axes[idx].axvline(mean_val, linestyle='--', color = hist_colors[idx])  # 평균선
    axes[idx].set_title(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 문제 1-4. 비즈니스 인사이트 정리
#
# Part 1의 분석 결과를 바탕으로 다음을 정리하세요.
#
# 1. 고객 특성 요약 (연령, 소득, 소비 특성)
# 2. 핵심 발견 사항 (분포 특성, 그룹 간 차이)
# 3. 후속 분석에서 검증할 가설 (최소 3개)

# %%
# TODO 1-4: 비즈니스 인사이트 정리
print('주요 고객층의 연령은 50대 초반으로 추정가능하다.')
print('주요 고객의 가구 소득은 51000대로 형성되어 있다.')
print('소비 정도는 편차가 엄청 크다. 소량 소비가 대다수이고, 소비의 규모가 큰 경우는 거의 없다.')
print('소득 수준이 높아질수록 소비가 많아지는 경향을 보인다.')


print(f'검증 가설: ')
print(f'연령대에 따라 소비 금액의 차이는 존재할 것이다.')
print(f'소득 수준에 따라 주요 소비 품목이 달라질 것이다.')
print(f'연령대 별로 주요 소비 품목이 달라질 것이다.')
# Out:
# 주요 고객층의 연령은 50대 초반으로 추정가능하다.
# 주요 고객의 가구 소득은 51000대로 형성되어 있다.
# 소비 정도는 편차가 엄청 크다. 소량 소비가 대다수이고, 소비의 규모가 큰 경우는 거의 없다.
# 소득 수준이 낮은 그룹과 중간인 그룹에서 소비 규모의 차이가 컸다. 확실히 소득이 중간인 그룹의 소비 금액이 높게 형성되어 있었다. 오히려 소득 수준이 높은 그룹은 소비 가격이 낮게 형성되어있다.
# 검증 가설:
# 연령대에 따라 소비 금액의 차이는 존재할 것이다.
# 소득 수준에 따라 주요 소비 품목이 달라질 것이다.
# 연령대 별로 주요 소비 품목이 달라질 것이다.

# %% [markdown]
# ---
# ## Part 2: 확률분포 모델링 — "고객 행동은 어떤 패턴을 따르는가?"
#
# 실제 고객 데이터에 이론적 확률분포를 적합하여 고객 행동을 모델링합니다.

# %% [markdown]
# ### 문제 2-1. 이항분포 — 캠페인 수락 모델링
#
# `Response` 열에서 수락률 p를 계산하고, 이를 이항분포 B(n, p)에 적용합니다.
#
# - **(a)** 10명 중 정확히 2명이 수락할 확률
#   - B(n=10, p) 에서 P(X = 2) 계산
#
# - **(b)** 10명 중 3명 이상이 수락할 확률
#   - B(n=10, p) 에서 P(X ≥ 3) 계산
#
# - **(c)** 이항분포 PMF 시각화
#   - B(n=10, p) 의 모든 경우(X = 0, 1, ..., 10)에 대한
#     이론 확률을 막대그래프로 그립니다.
#
# - **(d)** n=100 으로 확장 — 세 가지 질문
#   - **기대 수락자 수**: E(X) 계산
#   - **15명 이상 수락 확률**: P(X ≥ 15) 계산
#   - **90% 보장 최소 수락 수**: P(X ≤ k) ≥ 0.90 을 만족하는 최솟값 k 탐색

# %%
# TODO 2-1(a),(b): 수락률(p) 계산 + P(X=2), P(X≥3) 계산 및 출력
n_trial = 10
p = df['Response'].mean()
display(p)
binom_df = stats.binom(n_trial,p)
print(f'a: 10명 중 정확히 2명이 수락할 확률 = {binom_df.pmf(2)}')
print(f'a: 10명 중 3명 이상이 수락할 확률 = {binom_df.sf(2)}')
# Out:
# np.float64(0.14937388193202147)
# a: 10명 중 정확히 2명이 수락할 확률 = 0.27521465499368963
# a: 10명 중 3명 이상이 수락할 확률 = 0.17818029736723678

# %%
# TODO 2-1(c): 이항분포 PMF 시각화
fig, ax = plt.subplots(figsize = (6,3))
k = np.arange(0,10)
ax.bar(k,binom_df.pmf(k))
ax.set_xlabel(f'n: {n_trial}, p: {p:.2f}인 이항분포')
plt.tight_layout()

# %%
# TODO 2-1(d): 100명 발송 시 기대 수락자, P(X≥15), 90% 보장 최소 수락 수
n_campaign = 100
binom_df2 = stats.binom(n_campaign,p)
print(f'e_x = {n_campaign*p:.2f}')
print(f'p(x>=15) = {binom_df2.sf(14)}')
print(f'90%보장 최소 수락 수 = {binom_df2.ppf(0.9)}')
# Out:
# e_x = 14.94
# p(x>=15) = 0.5358059894078708
# 90%보장 최소 수락 수 = 20.0

# %% [markdown]
# ### 문제 2-2. 포아송 분포 — 웹사이트 방문 모델링
#
# `NumWebVisitsMonth`(월간 웹 방문 수)에 포아송 분포를 적합합니다.
#
# - **(a)** λ 추정 및 적합 평가
#   - 표본 평균으로 λ를 추정하고,
#     표본 평균 ≈ 표본 분산인지 확인하여 포아송 분포 적합 여부를 평가합니다.
#
# - **(b)** 실측 vs 이론 PMF 시각화
#   - 각 방문 횟수(0회, 1회, 2회, ...)별 실제 비율(실측 PMF)과
#     포아송 분포의 이론 확률(이론 PMF)을 막대그래프로 겹쳐 그려 비교합니다.
#
# - **(c)** 포아송 분포 활용 — 두 가지 실무 시나리오
#   - **과다 방문 고객 비율**: P(X ≥ 10) 계산
#     → 추정된 포아송 분포에서 월 10회 이상 방문할 확률이 몇 %인지 구합니다.
#   - **서버 용량 계획**: 상위 5% 기준값 k 계산, 즉 P(X ≤ k) = 0.95 를 만족하는 k 탐색
#     → 전체 고객의 95%를 커버할 수 있는 최대 방문 횟수를 구하고,
#        이를 서버가 처리해야 할 기준 용량으로 활용합니다.

# %%
web_visits = df['NumWebVisitsMonth']

# TODO 2-2(a): 람다 추정 및 포아송 적합 평가 (월간 웹 방문수 평균≈분산 값이 비슷한지 확인)
w_mean = web_visits.mean()
w_var = web_visits.var(ddof=1)
print(f'평균: {w_mean}, 표본분산: {w_var}')
print('var/mean= 약 1.11로, 평균과 표본분산은 유사하다고 판단, 포아송 분포에 적합하다고 판단한다.')
# Out:
# 평균: 5.318872987477639, 표본분산: 5.889773404889684
# var/mean= 약 1.11로, 평균과 표본분산은 유사하다고 판단, 포아송 분포에 적합하다고 판단한다.

# %%
web_visits
# Out:
# 0       7
# 1       5
# 2       4
# 3       6
# 4       5
#        ..
# 2235    5
# 2236    7
# 2237    6
# 2238    3
# 2239    7
# Name: NumWebVisitsMonth, Length: 2236, dtype: int64

# %%
# TODO 2-2(b): 월간 웹 방문수 막대그래프 vs 이론 PMF 비교 시각화 (두 그래프를 겹쳐서 그리기)
x_pois = stats.poisson(mu = w_mean)
counts = web_visits.value_counts().sort_index()  # 값 기준 오름차순 정렬
x = counts.index
y = counts.values
fig, ax = plt.subplots(figsize = (8,5))
ax.bar(x,y,color = COLORS['blue'],label = '실제', alpha=0.6)
ax.bar(x,x_pois.pmf(x)*len(web_visits), color = COLORS['red'], label = '이론', alpha= 0.2)
ax.set_title('관측 vs 이론 막대그래프')
ax.legend()
plt.show()

# %%
# TODO 2-2(c):
# - 과다 방문 고객: 포아송 분포로 P(X ≥ 10) 계산 (월 10회 이상 방문 확률)
# - 서버 용량 계획: P(X ≤ k) ≥ 0.95 를 만족하는 최솟값 k 탐색 (상위 5% 기준)
heavy_threshold = 10

more_10 = x_pois.sf(9)
print(f'10번 이상 방문 이론: {more_10:.6f}')
more_10_real = (web_visits >= 10).mean()
print(f'10번 이상 방문 실제: {more_10_real:.6f}')

more_p_95 = x_pois.ppf(0.95)
more_p_95_real = web_visits.quantile(0.95)
print(f'95%이상 이론: {more_p_95}')
print(f'95%이상 실제: {more_p_95_real}')
# Out:
# 10번 이상 방문 이론: 0.044919
# 10번 이상 방문 실제: 0.005367
# 95%이상 이론: 9.0
# 95%이상 실제: 8.0

# %% [markdown]
# ### 문제 2-3. 정규분포 — 소득 모델링
#
# `Income`에 정규분포를 적합합니다.
# Part 1에서 Income의 왜도가 작고 평균≈중앙값임을 확인했습니다. 정규분포가 잘 맞을까요?
#
# - **(a)** μ, σ 추정 후 CDF로 P(Income < 30000), P(Income > 80000) 계산,
#  PPF로 상위 10% 소득 기준값 계산 — **이론 확률과 실측 비율을 비교**하세요
# - **(b)** 히스토그램 + 정규 분포 PDF와 겹쳐 그리기
# - **(c)** 정규분포 활용 — 두 가지 질문
#   - **VIP 기준선**: 상위 5% 소득 기준값
#     → "이 금액 이상이면 VIP 고객으로 분류"
#   - **할인 대상 기준선**: 하위 10% 소득 기준값
#     → "이 금액 이하이면 할인 대상 고객으로 분류"

# %%
# TODO 2-3(a): μ, σ 추정 → CDF로 P(Income<30000), P(Income>80000) 계산
#               PPF로 상위 10% 소득 기준값 계산 → 이론 확률과 실측 비율 비교
income = df['Income']
mu = income.mean()
sigma = income.std()
norm_dist = stats.norm(loc = mu, scale = sigma)
p_under_30000 = norm_dist.cdf(30000)
p_under_30000_real = (income < 30000).mean()
print(f'소득 30000 이상 비율 이론: {p_under_30000:.6f}, 실제: {p_under_30000_real:.6f}')

p_over_80000 = norm_dist.sf(80000)
p_over_80000_real = (income > 80000).mean()
print(f'소득 80000 이상 비율 이론: {p_over_80000:.6f}, 실제: {p_over_80000_real:.6f}')
# Out:
# 소득 30000 이상 비율 이론: 0.152617, 실제: 0.165474
# 소득 80000 이상 비율 이론: 0.095111, 실제: 0.096154

# %%
# TODO 2-3(b): 히스토그램 + 정규 PDF 겹쳐 그리기
income_x = np.linspace(income.max(),income.min(),300)
fig, ax = plt.subplots(figsize = (8,5))
ax.hist(income, label='실제',color=COLORS['blue'],density=True,bins=30)
ax.plot(income_x,norm_dist.pdf(income_x), color = COLORS['red'], label = '이론')
ax.set_xlabel('income')
ax.set_title('관측 히스토그램과 이론 pdf line')
ax.legend()
plt.show()

# %%
# TODO 2-3(c): 실무 시나리오 — VIP(상위 5%) 기준선 + 할인 대상(하위 10%) 기준선
print(f'이론적 vip: {norm_dist.ppf(0.95):.2f}')
print(f'관측적 vip: {income.quantile(0.95):.2f}')
print(f'이론적 할인 대상: {norm_dist.ppf(0.1):.2f}')
print(f'관측적 할인 대상: {income.quantile(0.1):.2f}')
# Out:
# 이론적 vip: 87171.34
# 관측적 vip: 83897.50
# 이론적 할인 대상: 24512.72
# 관측적 할인 대상: 24213.50

# %% [markdown]
# ---
# ## Part 3: 추정과 가설검정 — "고소득 고객과 저소득 고객의 소비는 다른가?"
#
# 신뢰구간과 가설검정을 통해 고객 그룹 간 차이를 통계적으로 검증합니다.

# %% [markdown]
# ### 문제 3-1. 신뢰구간 추정
#
# - **(a)** Total_Spending 평균의 90%, 95%, 99% 신뢰구간을 계산하세요.
# - **(b)** Income_Group별 95% CI를 계산하고 오차막대 그래프로 비교하세요.
#
# CI = [x̄ - t × SE, x̄ + t × SE] (SE = s / √n)

# %%
# TODO 3-1(a): Total_Spending 평균의 신뢰구간 (90%, 95%, 99%)
# CI = x̄ ± t(α/2, n-1) × SE
df3 = df['Total_Spending']
n = len(df3)

for a in [0.90,0.95,0.99]:
    ci = stats.t.interval(a,df=n-1 ,loc = df3.mean(), scale = df3.sem(ddof=1))
    print(f'{a*100}% 신뢰구간: [{ci[0]:.2f} , {ci[1]:.2f}]')
# Out:
# 90.0% 신뢰구간: [585.04 , 626.93]
# 95.0% 신뢰구간: [581.03 , 630.95]
# 99.0% 신뢰구간: [573.17 , 638.80]

# %%
# TODO 3-1(b): Income_Group별 95% CI 계산 + 오차막대 그래프
group = ['Low','Mid','High']

for g in group:
    g_df = df[df['Income_Group'] == g]['Total_Spending']
    g_n = len(df[df['Income_Group'] == g])
    ci = stats.t.interval(0.95,df = g_n-1, loc = g_df.mean(), scale = g_df.sem(ddof=1))
    print(f'{g} 95% 신뢰구간: [{ci[0]:.2f} , {ci[1]:.2f}]')
    
sns.barplot(df, x = 'Income_Group', y = 'Total_Spending', errorbar=('ci',95))
# Out:
# Low 95% 신뢰구간: [86.73 , 104.62]
# Mid 95% 신뢰구간: [431.47 , 484.39]
# High 95% 신뢰구간: [1231.35 , 1298.72]
# <Axes: xlabel='Income_Group', ylabel='Total_Spending'>

# %% [markdown]
# ### 문제 3-2. 독립표본 t-검정 (Welch's t-test)
#
# **가설**: 자녀가 없는 고객의 총 소비가 자녀가 있는 고객과 다른가?
#
# - H₀: μ_무자녀 = μ_유자녀
# - H₁: μ_무자녀 ≠ μ_유자녀
#
# Cohen's d 해석 기준: |d| < 0.5 작은, 0.5~0.8 중간, > 0.8 큰 효과

# %%
no_child = df[~df['Has_Children']]['Total_Spending']
yes_child = df[df['Has_Children']]['Total_Spending']

# TODO 3-2: Welch's t-검정 수행 + Cohen's d 계산 + 결과 출력
ttest = pg.ttest(no_child, yes_child, alternative='two-sided',correction=True)
d = ttest['cohen-d'].values[0]
print(ttest['cohen-d'])
display(ttest)

print('p-value가 유의수준보다 작으므로 귀무가설 기각, 효과크기 도한 1.35로 매운 큰 값이므로, 자녀 유무에 따라 소비의 차이가 크다고 할 수 있다.')
# Out:
# T-test    1.359854
# Name: cohen-d, dtype: float64
#                 T         dof alternative          p-val            CI95%  \
# T-test  24.988853  893.241096   two-sided  6.321230e-105  [642.82, 752.4]
#
#          cohen-d        BF10 power
# T-test  1.359854  5.963e+117   NaN
# p-value가 유의수준보다 작으므로 귀무가설 기각, 효과크기 도한 1.35로 매운 큰 값이므로, 자녀 유무에 따라 소비의 차이가 크다고 할 수 있다.

# %%
# TODO 3-2(c): 박스플롯 비교 시각화
sns.boxplot(data = df, x = 'Has_Children', y = 'Total_Spending')
plt.show()

# %% [markdown]
# ### 문제 3-3. 대응표본 t-검정
#
# 같은 고객의 **와인 소비**(`MntWines`)와 **육류 소비**(`MntMeatProducts`)를 비교합니다.
#
# - H₀: μ_Wine = μ_Meat (차이 = 0)
# - H₁: μ_Wine ≠ μ_Meat

# %%
wines = df['MntWines']
meat = df['MntMeatProducts']
diff = wines - meat
# TODO 3-3: 차이 계산 + 대응표본 t-검정 + Cohen's d + 결과 출력
diff_t = pg.ttest(wines,meat,paired = True, alternative = 'two-sided')
display(diff_t)
# p-value가 매우 작으므로 귀무가설 기각, 와인과 육류 소비의 차이가 있다고 판정할 수 있다. 효과크기는 작은 크기이므로, 그 차이가 크다고 하긴 힘들다.
# Out:
#                 T   dof alternative          p-val            CI95%   cohen-d  \
# T-test  23.092889  2235   two-sided  5.391927e-106  [125.5, 148.79]  0.478592
#
#              BF10  power
# T-test  1.28e+102    1.0

# %%
# TODO 3-3(b): (1) 대응 차이 히스토그램 (2) 카테고리별 평균 비교 막대그래프
sns.histplot(diff, color=COLORS['red'])
plt.show()

df_melt = pd.melt(df[['MntWines', 'MntMeatProducts']], var_name='category',value_name='spend')

sns.barplot(df_melt, x = 'category', y = 'spend')
# Out:
# <Axes: xlabel='category', ylabel='spend'>

# %% [markdown]
# ### 문제 3-4. 검정력 분석
#
# - **(a)** 문제 3-2의 효과 크기와 표본 크기를 사용하여 검정력(Power)을 계산하세요.
# - **(b)** 작은 효과(d=0.2)를 탐지하기 위해 필요한 그룹당 표본 크기를 구하세요.

# %%
power_analysis = TTestIndPower()

# TODO 3-4(a): 문제 3-2 기준 검정력 계산

power = power_analysis.solve_power(
    effect_size = d.round(1), #소수 둘째자리부터 인식이 안되는 듯 합니다..?
    nobs1 = len(no_child),
    ratio = len(yes_child) / len(no_child),
    alpha = 0.05,
    alternative = 'two-sided' 
)
print(power)
# TODO 3-4(b): 작은 효과(d=0.2) 탐지에 필요한 표본 크기 산정

need_n = power_analysis.solve_power(
    effect_size = 0.2,
    ratio = 1,
    power = 0.8,
    alpha = 0.5,
    alternative = 'two-sided'
)

print(need_n)
# Out:
# 1.0
# 106.50746146579695

# %% [markdown]
# ---
# ## Part 4: 고급 검정 — "교육, 결혼, 캠페인 반응의 관계는?"
#
# 정규성 검정을 바탕으로 적절한 검정 방법을 선택하고,
# 범주형 변수 간 관계를 분석합니다.

# %% [markdown]
# ### 문제 4-1. 정규성 + 등분산 검정
#
# Education_Group별 Total_Spending의 정규성을 Shapiro-Wilk 검정과 Q-Q Plot으로 확인하세요.
# 정규성이 기각되더라도, 표본이 충분히 크면(n ≥ 30) 중심극한정리(CLT)에 의해
# ANOVA가 여전히 강건(robust)합니다. 각 그룹의 표본 크기도 함께 확인하세요.
#
# ⚠️ **등분산성 위반은 CLT와 무관합니다** — 표본이 아무리 커도 해결되지 않습니다.
# Levene 검정으로 등분산 가정을 확인하고, 위반 시 Welch's ANOVA를 사용합니다.

# %%
edu_groups = ['Undergraduate', 'Graduate', 'Postgraduate']

# TODO 4-1(a): Shapiro-Wilk 검정 (각 그룹별)
for g in edu_groups:
    stat_sw, p_sw = stats.shapiro(df[df['Education_Group']==g]['Total_Spending'])
    print(f"{g}의 {p_sw:}: {'통과' if p_sw >=0.05 else '기각'}")
#모두 정규성을 위반한다.
# TODO 4-1(b): Levene 등분산 검정 → use_welch = True/False 설정
stat_l,p_l =stats.levene(*[df[df['Education_Group']==g]['Total_Spending'] for g in edu_groups])
print(p_l)
use_welch = True
# Out:
# Undergraduate의 5.543648052614619e-19: 기각
# Graduate의 3.561909628976696e-29: 기각
# Postgraduate의 1.7757879312718283e-25: 기각
# 1.8306692793099772e-06

# %%
# TODO 4-1(b): Q-Q Plot (1×3 서브플롯)
fig, axes = plt.subplots(1,3,figsize=(16,5))

for g , ax in zip(edu_groups,axes):
    stats.probplot(df[df['Education_Group']==g]['Total_Spending'],dist = 'norm',plot = ax)
    
plt.show()

# %% [markdown]
# ### 문제 4-2. ANOVA + 사후검정
#
# 문제 4-1의 정규성/등분산 검정 결과에 따라 적절한 검정을 수행합니다.
#
# - 등분산 만족 → One-way ANOVA + **Tukey HSD** + Cohen's d
# - 등분산 위반 → Welch's ANOVA + **Games-Howell** (`pg.pairwise_gameshowell()`) + Hedges' g
# - 참고로 비모수 검정(Kruskal-Wallis)도 병행하여 결과의 일관성을 확인하세요.
# - 효과 크기: η² + ω² (기준: 0.01 작은, 0.06 중간, 0.14 큰)
# - 쌍별 효과 크기: Cohen's d / Hedges' g (기준: 0.2 미만 매우 작은, 0.2~0.5 작은, 0.5~0.8 중간, 0.8 이상 큰)

# %%
group_data = {g: df[df['Education_Group'] == g]['Total_Spending'].values for g in edu_groups}
#welch's ANOVA 선택

# TODO 4-2(a): use_welch에 따라 ANOVA / Welch's ANOVA 수행 (Kruskal-Wallis도 병행)
anova = pg.welch_anova(data = df , dv='Total_Spending', between='Education_Group')
display(anova)
kw = pg.kruskal(data = df , dv='Total_Spending', between='Education_Group')
display(kw)
print(f'귀무가설 기각, 통계적으로 교육 그룹 간 소비에 유의한 차이가 있다고 할 수 있다.')
# TODO 4-2(b): η² + ω² 계산 — ω² = (SS_between - (k-1)*MS_within) / (SS_total + MS_within)
result = pg.anova(data = df , dv='Total_Spending', between='Education_Group',detailed = True)
display(result)
ss = result['SS'][0]
df_k1 = result['DF'][0]
ms = result['MS'][1]
sst = result['SS'].sum()
omega_square = (ss - df_k1*ms) / (sst + ms)
print(omega_square) #  ω²
print(result['np2'][0]) #  η²   효과 크기가 작다!
# Out:
#             Source  ddof1       ddof2          F         p-unc     np2
# 0  Education_Group      2  751.708152  19.817377  4.098696e-09  0.0137
#                   Source  ddof1          H         p-unc
# Kruskal  Education_Group      2  36.613323  1.120774e-08
# 귀무가설 기각, 통계적으로 교육 그룹 간 소비에 유의한 차이가 있다고 할 수 있다.
#             Source            SS    DF            MS          F         p-unc  \
# 0  Education_Group  1.109189e+07     2  5.545944e+06  15.508841  2.046193e-07
# 1           Within  7.985182e+08  2233  3.575989e+05        NaN           NaN
#
#       np2
# 0  0.0137
# 1     NaN
# 0.01281123840913708
# 0.013700282366187278

# %%
# TODO 4-2(c): 사후검정 수행 + 해석 + 쌍별 효과크기
# 등분산 만족 → Tukey HSD + Cohen's d
# 등분산 위반 → Games-Howell (pg.pairwise_gameshowell) + Hedges' g
gh = pg.pairwise_gameshowell(data = df, dv='Total_Spending', between='Education_Group')
display(gh) # 모든 그룹 간 차이가 있다. 하지만 효과 크기 자체는 작으므로, 크게 차이는 나지 않는다고 볼 수 있다.
# Out:
#               A              B     mean(A)     mean(B)        diff         se  \
# 0      Graduate   Postgraduate  620.394316  644.791813  -24.397497  27.691976
# 1      Graduate  Undergraduate  620.394316  412.254902  208.139414  36.852786
# 2  Postgraduate  Undergraduate  644.791813  412.254902  232.536911  38.554847
#
#           T           df          pval    hedges
# 0 -0.881031  1808.339544  6.523632e-01 -0.040121
# 1  5.647861   425.032927  8.920656e-08  0.355688
# 2  6.031328   492.811108  9.577128e-09  0.389636

# %%
# TODO 4-2(d): 시각화 — 그룹별 개별 데이터 산점도 + 평균 다이아몬드
fig, ax = plt.subplots(figsize = (10,5))
sns.stripplot(data = df, x = 'Total_Spending', y = 'Education_Group' ,order=edu_groups, ax=ax)
sns.pointplot(data = df, x = 'Total_Spending', y = 'Education_Group' ,order=edu_groups, ax=ax, color=COLORS['red'], markers='d',errorbar=None,
              estimator='median')
plt.show()

# %% [markdown]
# ### 문제 4-3. 카이제곱 독립성 검정
#
# **가설**: 결혼 상태(Marital_Group)와 캠페인 반응(Campaign_Response)은 독립인가?
#
# - H₀: Marital_Group과 Campaign_Response는 독립이다.
# - H₁: 두 변수는 독립이 아니다.
#
# - 효과크기: φ (phi) = √(χ² / n) (기준: 0.1 작은, 0.3 중간, 0.5 큰)
# - 오즈비(Odds Ratio): OR = (a×d) / (b×c), 95% CI = exp(ln(OR) ± 1.96 × SE)
#
# > ⚠️ Cochran 규칙: 기대빈도 < 5인 셀이 전체의 20% 초과 시 Fisher 정확검정 필요

# %%
crosstab_no_margin = pd.crosstab(df['Marital_Group'], df['Campaign_Response'])
display(crosstab_no_margin)
chi2, p, dof, expected = stats.chi2_contingency(crosstab_no_margin)
print(chi2, p, dof)
display(expected)

# TODO 4-3(a): 카이제곱 검정 수행 + Cochran 규칙 확인
chi2, p, dof, expected = stats.chi2_contingency(crosstab_no_margin)
print(chi2, p, dof)
display(expected)
# 규칙 만족
# TODO 4-3(b): φ (phi) 계산
n_sample = crosstab_no_margin.sum().sum()
phi = np.sqrt(chi2 / n_sample)
print(phi) # 매우 작은 크기

# TODO 4-3(c): 오즈비(Odds Ratio) + 95% CI 계산
a = crosstab_no_margin.loc['Single',True] #bool
b = crosstab_no_margin.loc['Single',False]
c = crosstab_no_margin.loc['Together',True]
d = crosstab_no_margin.loc['Together',False]
# 미혼인 사람의 응답 오즈가 기혼자의 오즈의 1.35
oz = (a/b) / (c/d)
print(oz)
ln_or = np.log(oz)

se = np.sqrt(1/a + 1/b + 1/c + 1/d)

lower_oz = np.exp(ln_or - 1.96 * se)
upper_oz = np.exp(ln_or + 1.96 * se)

print(f'95% CI: [{lower_oz:.4f}, {upper_oz:.4f}]')
# Out:
# Campaign_Response  False  True
# Marital_Group
# Single               547    247
# Together            1081    361
# 9.236758434275565 0.002372044985880111 1
# array([[ 578.10017889,  215.89982111],
#        [1049.89982111,  392.10017889]])
# 9.236758434275565 0.002372044985880111 1
# array([[ 578.10017889,  215.89982111],
#        [1049.89982111,  392.10017889]])
# 0.06427230766297097
# 1.3521601077648415
# 95% CI: [1.1162, 1.6380]

# %%
# TODO 4-3(d): (1) 결혼 상태별 반응률 막대그래프 (2) 표준화 잔차 히트맵
crosstab_no_margin.plot(kind='bar')
# Out:
# <Axes: xlabel='Marital_Group'>

# %%
residuals = (crosstab_no_margin - expected) / np.sqrt(expected)
display(residuals)
sns.heatmap(residuals, annot=True)
# Out:
# Campaign_Response     False     True
# Marital_Group
# Single            -1.293485  2.116590
# Together           0.959818 -1.570596
# <Axes: xlabel='Campaign_Response', ylabel='Marital_Group'>

# %% [markdown]
# ### 문제 4-4. 적합도 검정
#
# 3개 구매 채널(Web, Catalog, Store)의 총 구매 비율이 균등하게 분포하는지 검정합니다.
#
# - H₀: 세 채널의 구매 비율이 동일하다 (1/3 : 1/3 : 1/3)
# - H₁: 세 채널의 구매 비율이 동일하지 않다
#
# Cohen's w = √(Σ(p_obs - p_exp)² / p_exp)

# %%
channel_totals = df[purchase_cols].sum()
channel_names = ['Web', 'Catalog', 'Store']
observed = channel_totals.values
display(observed)
display(expected)
# TODO 4-4(a): 기대빈도(균등) 계산 + 적합도 검정
expected = np.full(3,observed.sum()/3)
expected
chi2, p_gof = stats.chisquare(observed, expected) #통계적으로 유의하다! 세 채널의 구매 비율은 동일하지 않다.

print(chi2, p_gof)

# TODO 4-4(b): Cohen's w 계산
n_total = observed.sum()
cohens_w = np.sqrt(chi2 / n_total)
print(cohens_w) # 중간 정도의 효과 크기를 보인다.
# Out:
# array([ 9140,  5955, 12959])
# array([[ 578.10017889,  215.89982111],
#        [1049.89982111,  392.10017889]])
# 2630.1062950024952 0.0
# 0.3061887670972692

# %%
# TODO 4-4(c): 관측 vs 기대(균등) 비교 막대그래프
fig, ax = plt.subplots(figsize = (8,5))
x=channel_names
ax.bar(x,observed, color='blue', alpha= 0.4, label = 'observed')
ax.bar(x,expected, color='red', alpha= 0.5, label = 'expected')
ax.set_title('관측 vs 기대(균등) 비교 막대그래프')
plt.tight_layout()
plt.legend()

# %% [markdown]
# ---
# ## Part 5: 상관분석 / 비율 비교 — "변수 간 관계를 파악하고, 캠페인 효과를 검증할 수 있는가?"
#
# 변수 간 상관관계를 분석하고, A/B 테스트로 캠페인 효과를 검증합니다.

# %% [markdown]
# ### 문제 5-1. 상관분석
#
# 6개 변수의 Pearson/Spearman 상관계수를 계산하고 히트맵으로 시각화하세요.
# 주요 변수 쌍에 대해 유의성 검정도 수행합니다.

# %%
corr_vars = ['Income', 'Age', 'Total_Spending', 'Total_Purchases',
             'NumWebVisitsMonth', 'Recency']

# TODO 5-1(a): Pearson/Spearman 상관행렬 계산
# pg.pairwise_corr로 주요 결과를 가져오는 것과, .corr로 상관행렬만 가져오는 방법 두 가지 모두 사용
q5 = df[corr_vars]
q5_pearson = pg.pairwise_corr(q5,method='pearson')
q5_pearson1 = q5.corr(method='pearson')
display(q5_pearson)
display(q5_pearson1)
q5_spearman = pg.pairwise_corr(q5,method='spearman')
q5_spearman1 = q5.corr(method='spearman')
display(q5_spearman)
display(q5_spearman1)
# Out:
#                     X                  Y   method alternative     n         r  \
# 0              Income                Age  pearson   two-sided  2236  0.198835
# 1              Income     Total_Spending  pearson   two-sided  2236  0.789375
# 2              Income    Total_Purchases  pearson   two-sided  2236  0.738647
# 3              Income  NumWebVisitsMonth  pearson   two-sided  2236 -0.646382
# 4              Income            Recency  pearson   two-sided  2236  0.007829
# 5                 Age     Total_Spending  pearson   two-sided  2236  0.113618
# 6                 Age    Total_Purchases  pearson   two-sided  2236  0.173004
# 7                 Age  NumWebVisitsMonth  pearson   two-sided  2236 -0.117498
# 8                 Age            Recency  pearson   two-sided  2236  0.019396
# 9      Total_Spending    Total_Purchases  pearson   two-sided  2236  0.821091
# 10     Total_Spending  NumWebVisitsMonth  pearson   two-sided  2236 -0.499909
# 11     Total_Spending            Recency  pearson   two-sided  2236  0.020842
# 12    Total_Purchases  NumWebVisitsMonth  pearson   two-sided  2236 -0.426734
# 13    Total_Purchases            Recency  pearson   two-sided  2236  0.006426
# 14  NumWebVisitsMonth            Recency  pearson   two-sided  2236 -0.021850
#
#              CI95%          p-unc        BF10     power
# 0     [0.16, 0.24]   2.269594e-21   9.421e+17  1.000000
# 1      [0.77, 0.8]   0.000000e+00         inf  1.000000
# 2     [0.72, 0.76]   0.000000e+00         inf  1.000000
# 3   [-0.67, -0.62]  9.867293e-265  4.084e+260  1.000000
# 4    [-0.03, 0.05]   7.113696e-01       0.028  0.065822
# 5     [0.07, 0.15]   7.163790e-08   5.256e+04  0.999702
# 6     [0.13, 0.21]   1.746297e-16   1.416e+13  1.000000
# 7   [-0.16, -0.08]   2.514897e-08   1.449e+05  0.999852
# 8    [-0.02, 0.06]   3.592673e-01        0.04  0.150451
# 9     [0.81, 0.83]   0.000000e+00         inf  1.000000
# 10  [-0.53, -0.47]  1.072711e-141  6.252e+137  1.000000
# 11   [-0.02, 0.06]   3.245663e-01       0.043  0.166452
# 12  [-0.46, -0.39]   1.205638e-99     7.1e+95  1.000000
# 13   [-0.04, 0.05]   7.613769e-01       0.028  0.060624
# 14   [-0.06, 0.02]   3.017204e-01       0.045  0.178314
#                      Income       Age  Total_Spending  Total_Purchases  \
# Income             1.000000  0.198835        0.789375         0.738647
# Age                0.198835  1.000000        0.113618         0.173004
# Total_Spending     0.789375  0.113618        1.000000         0.821091
# Total_Purchases    0.738647  0.173004        0.821091         1.000000
# NumWebVisitsMonth -0.646382 -0.117498       -0.499909        -0.426734
# Recency            0.007829  0.019396        0.020842         0.006426
#
#                    NumWebVisitsMonth   Recency
# Income                     -0.646382  0.007829
# Age                        -0.117498  0.019396
# Total_Spending             -0.499909  0.020842
# Total_Purchases            -0.426734  0.006426
# NumWebVisitsMonth           1.000000 -0.021850
# Recency                    -0.021850  1.000000
#                     X                  Y    method alternative     n  \
# 0              Income                Age  spearman   two-sided  2236
# 1              Income     Total_Spending  spearman   two-sided  2236
# 2              Income    Total_Purchases  spearman   two-sided  2236
# 3              Income  NumWebVisitsMonth  spearman   two-sided  2236
# 4              Income            Recency  spearman   two-sided  2236
# 5                 Age     Total_Spending  spearman   two-sided  2236
# 6                 Age    Total_Purchases  spearman   two-sided  2236
# 7                 Age  NumWebVisitsMonth  spearman   two-sided  2236
# 8                 Age            Recency  spearman   two-sided  2236
# 9      Total_Spending    Total_Purchases  spearman   two-sided  2236
# 10     Total_Spending  NumWebVisitsMonth  spearman   two-sided  2236
# 11     Total_Spending            Recency  spearman   two-sided  2236
# 12    Total_Purchases  NumWebVisitsMonth  spearman   two-sided  2236
# 13    Total_Purchases            Recency  spearman   two-sided  2236
# 14  NumWebVisitsMonth            Recency  spearman   two-sided  2236
#
#            r           CI95%          p-unc     power
# 0   0.216515    [0.18, 0.26]   3.948422e-25  1.000000
# 1   0.849491    [0.84, 0.86]   0.000000e+00  1.000000
# 2   0.776796    [0.76, 0.79]   0.000000e+00  1.000000
# 3  -0.640295  [-0.66, -0.62]  3.024429e-258  1.000000
# 4   0.009743   [-0.03, 0.05]   6.451752e-01  0.074621
# 5   0.157677     [0.12, 0.2]   6.441612e-14  1.000000
# 6   0.179340    [0.14, 0.22]   1.285733e-17  1.000000
# 7  -0.129426  [-0.17, -0.09]   8.121773e-10  0.999986
# 8   0.020109   [-0.02, 0.06]   3.418833e-01  0.158186
# 9   0.908447     [0.9, 0.92]   0.000000e+00  1.000000
# 10 -0.476821  [-0.51, -0.44]  2.631604e-127  1.000000
# 11  0.019979   [-0.02, 0.06]   3.450079e-01  0.156756
# 12 -0.420867  [-0.45, -0.39]   1.065701e-96  1.000000
# 13  0.011726   [-0.03, 0.05]   5.794647e-01  0.085857
# 14 -0.022259   [-0.06, 0.02]   2.927563e-01  0.183296
#                      Income       Age  Total_Spending  Total_Purchases  \
# Income             1.000000  0.216515        0.849491         0.776796
# Age                0.216515  1.000000        0.157677         0.179340
# Total_Spending     0.849491  0.157677        1.000000         0.908447
# Total_Purchases    0.776796  0.179340        0.908447         1.000000
# NumWebVisitsMonth -0.640295 -0.129426       -0.476821        -0.420867
# Recency            0.009743  0.020109        0.019979         0.011726
#
#                    NumWebVisitsMonth   Recency
# Income                     -0.640295  0.009743
# Age                        -0.129426  0.020109
# Total_Spending             -0.476821  0.019979
# Total_Purchases            -0.420867  0.011726
# NumWebVisitsMonth           1.000000 -0.022259
# Recency                    -0.022259  1.000000

# %%
# TODO 5-1(b): 주요 상관계수 쌍의 유의성 검정 (stats.pearsonr)

#|r| >= 0.7 이상인 것만 선택 (stats.pearsonr 대신 pg.pairwise_corr의 결과를 가져왔습니다.)
q5_pmain = q5_pearson.loc[abs(q5_pearson['r'])>=0.5]
q5_smain = q5_spearman.loc[abs(q5_spearman['r'])>=0.5]


display(q5_pmain[['X','Y','r','p-unc','method']])
display(q5_smain[['X','Y','r','p-unc','method']])
# Out:
#                 X                  Y         r          p-unc   method
# 1          Income     Total_Spending  0.789375   0.000000e+00  pearson
# 2          Income    Total_Purchases  0.738647   0.000000e+00  pearson
# 3          Income  NumWebVisitsMonth -0.646382  9.867293e-265  pearson
# 9  Total_Spending    Total_Purchases  0.821091   0.000000e+00  pearson
#                 X                  Y         r          p-unc    method
# 1          Income     Total_Spending  0.849491   0.000000e+00  spearman
# 2          Income    Total_Purchases  0.776796   0.000000e+00  spearman
# 3          Income  NumWebVisitsMonth -0.640295  3.024429e-258  spearman
# 9  Total_Spending    Total_Purchases  0.908447   0.000000e+00  spearman

# %%
# TODO 5-1(c): 상관행렬 히트맵 (Pearson + Spearman, 1×2 서브플롯)

fig, ax = plt.subplots(1,2, figsize=(8,5))

mask = np.triu(np.ones_like(q5_pearson1, dtype=bool),k =1)

sns.heatmap(q5_pearson1,annot=True,fmt='.2f',mask = mask, ax = ax[0],cmap='coolwarm')
ax[0].set_title('Pearson 상관행렬')
plt.setp(ax[0].get_xticklabels(), rotation=45, ha='right')

sns.heatmap(q5_spearman1,annot=True,fmt='.2f',mask = mask, ax = ax[1], cmap='coolwarm')
ax[1].set_title('Spearman 상관행렬')
plt.setp(ax[1].get_xticklabels(), rotation=45, ha='right')
plt.tight_layout()

# %%
# TODO 5-1(d): 주요 변수 쌍 산점도 + 추세선 (1×3 서브플롯)
# 대상: (Income, Total_Spending), (NumWebVisitsMonth, Total_Spending), (Total_Spending, Total_Purchases)
# np.polyfit()으로 1차 추세선을 그리세요

fig, ax = plt.subplots(1,3 , figsize = (12,5))

ax[0].scatter(df['Income'], df['Total_Spending'], alpha = 0.7)
ax[0].set_title('Income - Total Spending')
z0 = np.polyfit(df['Income'], df['Total_Spending'],1)
p0 = np.poly1d(z0)
x0_line = np.linspace(df['Income'].min(), df['Income'].max(), 100)
ax[0].plot(x0_line, p0(x0_line), color='#EF4444', linewidth=2, linestyle='--',
        label=f'회귀선: y = {z0[0]:.2f}x + {z0[1]:.1f}')
ax[0].legend()
ax[0].set_xlabel('Income')
ax[0].set_ylabel('Total Spending')

ax[1].scatter(df['NumWebVisitsMonth'], df['Total_Spending'], alpha = 0.7)
ax[1].set_title('NumWebVisitsMonth - Total Spending')
z1 = np.polyfit(df['Income'], df['Total_Spending'],1)
p1 = np.poly1d(z0)
x1_line = np.linspace(df['NumWebVisitsMonth'].min(), df['NumWebVisitsMonth'].max(), 100)
ax[1].plot(x1_line, p1(x0_line), color='#EF4444', linewidth=2, linestyle='--',
        label=f'회귀선: y = {z1[0]:.2f}x + {z1[1]:.1f}')
ax[1].set_xlabel('NumWebVisitsMonth')
ax[0].set_ylabel('Total Spending')
ax[1].legend()


ax[2].scatter(df['Total_Purchases'], df['Total_Spending'], alpha = 0.7)
ax[2].set_title('Total_Purchases - Total Spending')
z2 = np.polyfit(df['Income'], df['Total_Spending'],1)
p2 = np.poly1d(z0)
x2_line = np.linspace(df['Total_Purchases'].min(), df['Total_Purchases'].max(), 100)
ax[2].plot(x1_line, p1(x0_line), color='#EF4444', linewidth=2, linestyle='--',
        label=f'회귀선: y = {z2[0]:.2f}x + {z2[1]:.1f}')
ax[2].set_xlabel('Total Purchases')
ax[2].set_ylabel('Total Spending')

ax[2].legend()

plt.tight_layout()

# %% [markdown]
# ### 문제 5-2. 두 그룹 비율 비교 (관찰 연구)
#
# 이전 캠페인 반응 경험 유무에 따라 마지막 캠페인(Response) 수락률에 차이가 있는지 검증합니다.
#
# - **Group A**: AcceptedCmp1~5 합계 = 0 (이전 캠페인 무반응)
# - **Group B**: AcceptedCmp1~5 합계 ≥ 1 (이전 캠페인 반응 경험)
# - **지표**: Response (마지막 캠페인 수락률)
# - **검정 방법**: z-비율검정 + Cohen's h + Wilson 신뢰구간
#
# > **주의**: 이 분석은 A/B 테스트가 **아닙니다**. \
# > A/B 테스트는 연구자가 참가자를 **무작위로 배정** (Random Assignment)하는 실험입니다. \
# > 여기서는 고객이 과거 행동에 의해 스스로 그룹에 배정되었으므로 **관찰 연구**이며, \
# > 인과관계를 주장할 수 없습니다.

# %%
cmp_cols = ['AcceptedCmp1', 'AcceptedCmp2', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5']
df['Prior_Response'] = df[cmp_cols].sum(axis=1)

group_a = df[df['Prior_Response'] == 0]
group_b = df[df['Prior_Response'] >= 1]

n_a, n_b = len(group_a), len(group_b)
conv_a = group_a['Response'].sum()
conv_b = group_b['Response'].sum()
rate_a = conv_a / n_a
rate_b = conv_b / n_b

# TODO 5-2(a): z-비율검정
z_t , z_p = proportions_ztest([conv_a,conv_b], [n_a , n_b] )
print(f'{z_t:.4f}, {z_p:}')  #두 그룹간 수락률에 차이가 있다!
# TODO 5-2(b): Cohen's h 효과 크기
cohen_h = proportion_effectsize(rate_a, rate_b)
print(cohen_h)# 두 그룹간 효과크기는 매우 크다(b가 더 크다.)

# TODO 5-2(c): Wilson 신뢰구간

ci_a = proportion_confint(conv_a, n_a, alpha=0.05, method='wilson') 
ci_b = proportion_confint(conv_b, n_b, alpha=0.05, method='wilson') 
print(ci_a)
print(ci_b)
# Out:
# -17.4357, 4.4217089462117046e-68
# -0.8016212123405796
# (0.07039586115479846, 0.09600899871214175)
# (0.3630763884032965, 0.4523114471540749)

# %%
# TODO 5-2(d): 수락률 비교 시각화 (CI 오차막대 포함)
fig, ax = plt.subplots(figsize = (12,5))
x = ['A(응답)', 'B(무응답)']
y = [rate_a,rate_b]
lower_errors = [
    rate_a - ci_a[0],
    rate_b - ci_b[0]
]

upper_errors = [
    ci_a[1] - rate_a,
    ci_b[1] - rate_b
]

yerr = [lower_errors, upper_errors]
ax.bar(x,y)
ax.errorbar(x,y,yerr=yerr, fmt = 'none',color = 'black')
ax.set_title('A, B 수락률 비교')
plt.tight_layout()
plt.show()

# %% [markdown]
# > ⚠️ **이 분석이 A/B 테스트가 아닌 이유**
# >
# > A/B 테스트의 본질은 '무작위 배정(Random Assignment)'입니다.
# >
# > - **A/B 테스트**: 연구자가 참가자를 무작위로 배정 → 인과관계 추론 가능
# > - **이 분석**: 고객의 과거 행동으로 그룹이 결정 → 관찰 연구, 인과관계 주장 불가
# >
# > → 인과관계를 검증하려면 무작위 배정 실험(RCT)을 설계해야 합니다. (문제 5-3)

# %% [markdown]
# ### 문제 5-3. 진정한 A/B 테스트 설계
#
# 새로운 캠페인이 기존 수락률 대비 **2%p** 개선을 가져올 수 있는지 탐지하기 위한
# 최소 표본 크기를 산정하세요. (α=0.05, Power=0.80)

# %%
baseline_rate = df['Response'].mean()
target_rate = baseline_rate + 0.02

# TODO 5-3(a): Cohen's h 계산
cohen_h1 = proportion_effectsize(baseline_rate, target_rate)
print(cohen_h1)
# TODO 5-3(b): NormalIndPower()로 필요 표본 크기 산정 (α=0.05, Power=0.80, 단측)
power_prob = NormalIndPower()
n_nob = power_prob.solve_power(
    effect_size=abs(cohen_h1),
    alpha = 0.05,
    power=0.80,
    ratio = 1,
    alternative='larger'
)
print(n_nob)

##최소 4138 * 2  = 8276명이 필요하다. (2개 집단)
# Out:
# -0.05466566903304804
# 4137.793429568724

# %% [markdown]
# ---
# ## Challenge: 종합 분석 보고서
#
# 지금까지의 분석을 종합하여 FreshCart 마케팅팀에 제출할 보고서를 작성합니다.

# %% [markdown]
# ### Challenge 1. 고객 그룹별 특성 분석
#
# `Income_Group` × `Has_Children` 6개 조합에 대해 다음을 포함하는 종합 분석표를 작성하세요:
#
# - 고객 수, 평균 소득, 평균/중앙값 소비, 평균 구매 수, 캠페인 반응률, 웹 방문 수
# - 그룹 비교 시각화 (1×3 서브플롯: 평균 소비, 반응률, 고객 수)

# %%
# TODO C-1: 고객 그룹별 특성 분석 종합표 + 시각화

results = df.groupby(['Income_Group','Has_Children']).agg(
    고객수 = ('ID','count'),
    평균소득 = ('Income','mean'),
    평균소비 = ('Total_Spending','mean'),
    중앙값소비 = ('Total_Spending','median'),
    평균구매수 = ('Total_Purchases', 'mean'),
    캠페인반응률 = ('Campaign_Response','mean'),
    웹방문수 = ('NumWebVisitsMonth','mean')
)
display(results)
# Out:
#                            고객수          평균소득         평균소비   중앙값소비      평균구매수  \
# Income_Group Has_Children
# Low          False         115  24380.243478   145.008696    73.0   6.400000
#              True          631  29172.879556    86.686212    54.0   5.670365
# Mid          False          80  52209.631250   721.237500   653.0  15.362500
#              True          665  51466.093985   426.254135   368.0  12.338346
# High         False         442  78697.963801  1424.024887  1383.0  19.219457
#              True          303  71841.607261  1033.115512  1005.0  19.178218
#
#                              캠페인반응률      웹방문수
# Income_Group Has_Children
# Low          False         0.130435  6.930435
#              True          0.169572  6.901743
# Mid          False         0.350000  4.675000
#              True          0.198496  5.869173
# High         False         0.545249  2.366516
#              True          0.280528  4.679868

# %%
chart_list = [('Total_Spending','평균 소비', '그룹별 평균 소비'),
              ('Campaign_Response','캠페인 반응률', '그룹별 캠페인 반응률'),
]

fig, axes = plt.subplots(1,3, figsize = (12,5))
for ax, (col,y,title) in zip(axes[:2],chart_list):
    sns.barplot(data = df, x = 'Income_Group', y = col, hue = 'Has_Children', ax=ax)
    ax.set_title(title)
    
sns.countplot(data = df, x = 'Income_Group', hue = 'Has_Children', ax = axes[2])    
axes[2].set_title('그룹별 고객 수')
plt.tight_layout()

# %% [markdown]
# ### Challenge 2. 비즈니스 제안서
#
# 분석 결과를 종합하여 다음을 포함하는 제안서를 작성하세요:
#
# 1. **타겟 고객**: 어떤 그룹를 우선 집중 공략해야 하는가? (근거 포함)
# 2. **채널 전략**: 소득 그룹별 최적 마케팅 채널은?
# 3. **기대 효과**: 집중 공략 기반 예상 개선 효과
# 4. **한계점**: 분석의 한계와 추가 필요 데이터

# %%
# TODO C-2: 비즈니스 제안서 작성

# 1. 소득 단계가 'High인 고객을 집중 공략해야 합니다. 이들의 소비량이 다른 그룹에 비해 압도적으로 많습니다.
# 또한 자녀가 없는 사람이 자녀가 있는 사람보다 소비가 많은 경향이 있습니다. 아무래도 자녀가 있는 그룹은 사치품을 잘 사지 않는 경향 때문이지 않을까 추측합니다.

# 2. 웹사이트 방문은 소득이 낮은 그룹에서 많고, 중간 이상 그룹부터는 횟수가 확 줄었습니다. 그래서 웹사이트는 따로 의미가 없는 것 같습니다. 최적 마케팅 채널을 찾기 위해선, 추가적인 조사가 필요해 보입니다.

# 3. 소득이 높은 그룹은 자녀가 없는 비율이 많습니다. 미혼, 기혼 여부가 판단이 되면 좋겠습니다만, 고가의 사치품을 이들의 기호에 맞춘다면, 유의미한 매출 상승을 가져올 수 있을 것 같습니다.

# 4. 자녀 여부에 추가로 기혼, 미혼 여부도 있다면 더 ㅣㅁ층적인 결과를 얻을 수 있을 것 같습니다.
# 또한 실제로 a/b 테스트를 진행하진 못했으므로, 충분한 표본의 데이터를 모아 추가적인 테스트를 진행하면 유의미한 결과가 나올 것입니다.

# %% [markdown]
# ---
# ## 수고하셨습니다!
#
# 설날 연휴 따뜻하고 복 가득한 시간 보내요! 💛
